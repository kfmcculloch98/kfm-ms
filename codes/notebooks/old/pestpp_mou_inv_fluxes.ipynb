# %%
import os, shutil, stat
from pathlib import Path

def on_rm_error(func, path, excinfo):
    # try to change file permission and retry
    try:
        os.chmod(path, stat.S_IWRITE)
        func(path)
    except Exception as e:
        print("on_rm_error could not remove:", path, type(e), e)

template_path = Path(r"C:\Python\Personal\proj6\codes\runs\pest\baseline_template")
os.chdir(Path.home())

print("Attempting robust rmtree on:", template_path)
try:
    shutil.rmtree(template_path, onerror=on_rm_error)
    print("Removed", template_path)
except Exception as e:
    print("Still failed:", type(e), e)
# Out:
# Attempting robust rmtree on: C:\Python\Personal\proj6\codes\runs\pest\baseline_template
# Removed C:\Python\Personal\proj6\codes\runs\pest\baseline_template

# %%
import os
import sys
import yaml
import shutil
import subprocess
import pyemu
import copy
from pathlib import Path

def prepare_MOU_files(objectives='model_misfit',
                      scenario_name=None,
                      param_set_selector=None,
                      use_log_transform=True,
                      r_lb=0.1,
                      r_ub=1e5):
    """
    Build template folder and PST for estimating well radial_dist (__r).
    - Measured fluxes are generated by running the forward model once with numeric inputs.
    - param_set_selector: None, int (index), or str (name) to pick param_set in base proj6.yml.
    - use_log_transform: if True, sets partrans='log' for radial parameters.
    - r_lb, r_ub: parameter bounds for radii (same units as radial_dist in proj6.yml).
    Returns: (scenario_name, template_path_str)
    """
    # 1. Setup Absolute Paths (adjust root if needed)
    root = Path(r"C:\Python\Personal\proj6\codes").resolve()
    pycap_run_name = "proj6"
    python_exe = sys.executable  # Path to python.exe to use when running the forward model

    if scenario_name is None:
        scenario_name = objectives

    parent_run_path = root / "runs"
    base_run_path = parent_run_path / "base"
    pest_path = parent_run_path / "pest"
    template_path = pest_path / f"{scenario_name}_template"
    script_source = root / "scripts" / "run_theis_forward.py"

    # 2. Clean & Recreate Template Folder
    if template_path.exists():
        import time
        try:
            shutil.rmtree(template_path)
        except PermissionError:
            time.sleep(1)
            shutil.rmtree(template_path)
    template_path.mkdir(parents=True, exist_ok=True)

    # 3. Read base proj6.yml and (optionally) apply param_set
    base_yml_path = base_run_path / f"{pycap_run_name}.yml"
    if not base_yml_path.exists():
        raise FileNotFoundError(f"Base proj6.yml not found at {base_yml_path}")

    with open(base_yml_path, 'r') as ifp:
        indat = yaml.safe_load(ifp)

    # apply param_set_selector if requested
    if param_set_selector is not None:
        ps = indat.get('param_sets', [])
        if isinstance(param_set_selector, int):
            if param_set_selector < 0 or param_set_selector >= len(ps):
                raise IndexError("param_set_selector index out of range")
            sel = ps[param_set_selector]
        else:
            matches = [p for p in ps if p.get('name') == str(param_set_selector)]
            if not matches:
                raise KeyError(f"No param_set named '{param_set_selector}'")
            sel = matches[0]
        for k in ('T', 'S', 't_eval'):
            if k in sel:
                indat[k] = sel[k]

    # 4. Create a numeric copy of proj6.yml (with numeric radial_dist) to run the forward model
    #    We'll run the forward model from template folder but with this numeric file first.
    numeric_cfg = copy.deepcopy(indat)
    # ensure wells have numeric radial_dist values (they currently do in base file)
    well_keys = [i for i in numeric_cfg.keys() if i.startswith('well_')]
    if not well_keys:
        raise RuntimeError("No well_ entries found in base proj6.yml")

    # 5. Write numeric proj6.yml into the template folder for the test forward-run
    numeric_proj6_path = template_path / f"{pycap_run_name}_numeric.yml"
    with open(numeric_proj6_path, 'w') as ofp:
        yaml.dump(numeric_cfg, ofp, default_flow_style=False, sort_keys=False)

    # 6. Copy run_theis_forward.py into template folder (so the exact script will be used)
    if not Path(script_source).exists():
        raise FileNotFoundError(f"Model script not found at {script_source}")
    shutil.copy(script_source, template_path / "run_theis_forward.py")

    # 7. Run forward model once to produce measured fluxes (allobs_meas.out)
    cwd = os.getcwd()
    os.chdir(template_path)
    try:
        # run python_proj6_numeric -> it expects proj6.yml name; our run_theis_forward supports
        # passing a selector, but easiest is to call the script with explicit config filename.
        # We'll run the script by invoking python and passing the numeric yaml as the config.
        # To support that the script needs to accept a config filename; if not, we temporarily
        # create proj6.yml with numeric values and run script normally.

        # Create a temporary proj6.yml (numeric) the model will read
        temp_infile = template_path / f"{pycap_run_name}.yml"
        with open(temp_infile, 'w') as ofp:
            yaml.dump(numeric_cfg, ofp, default_flow_style=False, sort_keys=False)

        # Run the model (use the python_exe that will also be used in MODEL_COMMAND)
        proc = subprocess.run([python_exe, "run_theis_forward.py"],
                              stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
        if proc.returncode != 0:
            # show stderr for debugging
            raise RuntimeError(f"Forward model run failed:\nSTDOUT:\n{proc.stdout}\nSTDERR:\n{proc.stderr}")

        # If model ran, read the produced allobs.out (these are our measured fluxes)
        meas_path = template_path / "allobs.out"
        if not meas_path.exists():
            # If model didn't produce it, error
            raise RuntimeError("Forward model did not produce allobs.out when run numerically.")
        # Read measured values and keep them for later
        measured_lines = meas_path.read_text().splitlines()
        measured = {}
        for ln in measured_lines:
            parts = ln.split()
            if len(parts) >= 2:
                measured[parts[0]] = float(parts[1])
    finally:
        # remove the numeric proj6.yml we created (we will write a tokenized version later)
        # but keep run_theis_forward.py copy and allobs.out (we want measured)
        if (template_path / f"{pycap_run_name}.yml").exists():
            # leave measured allobs.out in place
            pass
        os.chdir(cwd)

    # 8. Now parameterize radial_dist with tokens in indat, write .tpl and tokenized in-file
    #    Replace radial_dist with token like ~well_1__r~ in indat.
    for k in well_keys:
        # build token name, centered in field (same style as before)
        indat[k]['radial_dist'] = f"~{k + '__r':^20}~"

    # Write the tpl (template) file
    with open(template_path / f"{pycap_run_name}.yml.tpl", 'w') as ofp:
        ofp.write('ptf ~\n')
        yaml.dump(indat, ofp, default_flow_style=False, sort_keys=False)

    # Write the tokenized proj6.yml (this is the in-file PEST will substitute into)
    with open(template_path / f"{pycap_run_name}.yml", 'w') as ofp:
        yaml.dump(indat, ofp, default_flow_style=False, sort_keys=False)

    # 9. Create instruction file (maps model output to observations) and measured allobs.out (overwrite)
    with open(template_path / 'allobs.out.ins', 'w') as ofp:
        ofp.write('pif ~\n')
        for k in sorted(well_keys):
            ofp.write(f'l1 w !{k}!\n')

    # overwrite allobs.out with measured values we just generated
    with open(template_path / 'allobs.out', 'w') as ofp:
        for k in sorted(measured.keys()):
            ofp.write(f"{k} {measured[k]}\n")

    # 10. Build the PST Object from the files in the template folder
    cwd = os.getcwd()
    os.chdir(template_path)
    try:
        pst = pyemu.Pst.from_io_files(
            tpl_files=[f"{pycap_run_name}.yml.tpl"],
            in_files=[f"{pycap_run_name}.yml"],
            ins_files=["allobs.out.ins"],
            out_files=["allobs.out"]
        )

        # 11. Set model command so PEST runs the copied script with the same python
        pst.model_command = [f"{python_exe} run_theis_forward.py"]

        # 12. Configure parameters: set __r parameters adjustable, use log transform if requested
        # Identify radial parameters ending with __r
        r_mask = pst.parameter_data.parnme.str.endswith("__r")
        if use_log_transform:
            pst.parameter_data.loc[r_mask, "partrans"] = "log"
        else:
            pst.parameter_data.loc[r_mask, "partrans"] = "none"
        # set bounds (parlbnd/parubnd) and initial parval1 remain the values read from the tokenized in-file
        pst.parameter_data.loc[r_mask, "parlbnd"] = r_lb
        pst.parameter_data.loc[r_mask, "parubnd"] = r_ub
        # ensure they are adjustable (set parval1 from numeric_cfg if needed)
        # pyemu reads parval1 from the in-file numeric values before tokenization;
        # to be safe, set parval1 explicitly from the numeric_cfg we used earlier:
        for k in well_keys:
            parn = f"{k}__r"
            if parn in list(pst.parameter_data.parnme):
                # original numeric value was numeric_cfg[k]['radial_dist']
                val = float(numeric_cfg[k]['radial_dist'])
                pst.parameter_data.loc[pst.parameter_data.parnme == parn, "parval1"] = val

        # 13. Observation settings: keep observation group and weights
        pst.observation_data.loc[:, "obgnme"] = "less_misfit"
        # weight: set to 1.0 or 1/sigma if you have measurement errors
        pst.observation_data.loc[:, "weight"] = 1.0

        # 14. Control settings: turn on estimation (positive noptmax)
        pst.control_data.noptmax = 2  # change to how many iterations you want

        # 15. Write the PST
        pst.write(f"{scenario_name}.pst")
    finally:
        os.chdir(cwd)

    # 16. Return scenario name and template path
    return scenario_name, str(template_path)

# %%
import subprocess, os
name, path = prepare_MOU_files(scenario_name='baseline', param_set_selector=0)
os.chdir(path)
pest_exe = r"C:\Python\Personal\proj6\codes\binaries\PESTPP\windows\pestpp-mou.exe"
proc = subprocess.run([pest_exe, f"{name}.pst"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
print(proc.returncode)
print(proc.stdout)
print(proc.stderr)
# Out:
# noptmax:2, npar_adj:2, nnz_obs:2
# 0
#
#
#              pestpp-mou: multi-objective optimization under uncertainty
#
#                    by the PEST++ development team
#
# ...processing command line: ' C:\Python\Personal\proj6\codes\binaries\PESTPP\windows\pestpp-mou.exe baseline.pst'
# ...using serial run manager
#
#
# version: 5.2.24
# binary compiled on Nov 12 2025 at 12:05:03
# using control file: "baseline.pst"
# in directory: "C:\Python\Personal\proj6\codes\runs\pest\baseline_template"
# on host: "TTL-HBJ6674"
# on a(n) windows operating system
# with release configuration
# started at 03/13/26 14:58:39
#
# processing control file baseline.pst
# Note: 3 unused lines in pest control file, see rec file...
# checking model IO files...done
#               starting serial run manager ...
#
#
#   ---  initializing MOEA process  ---
# ...using 'nsga2' env selector
# ...using binary tournament mating pool selector
# ...'mou_save_population_every' less than/equal to zero, not saving generation-specific populations (and archives)
# using all adjustable parameters as decision variables:  2
# ...number of decision variables:  2
# ...max run fail:  3
# ...'opt_chance_points' = SINGLE, evaluating chance at representative point
# ...'mou_objectives' not passed, using all nonzero weighted obs and prior info eqs that use the proper obs group naming convention
# ...using the following observations as objectives:
#                         WELL_1   minimize
#                         WELL_2   minimize
# ...2 obs-based constraints/objectives, see rec file for listing
# ...not using chance constraints
# ...using particle swarm generator
# ...drawing initial dv population of size:  100
# checking for denormal values in dv population
# ... saved initial dv population to  baseline.0.dv_pop.csv
# ...running initial population of size 100
# ...running population of size  100
#
#
#
#     ---  starting serial run manager for 100 runs ---
#
#
# 03/13/26 14:58:39 processing template files with 1 threads...
# 03/13/26 14:58:39 done, took 0.001 seconds
# 03/13/26 14:58:39 calling forward run command(s)
# 03/13/26 14:58:39 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74184
# ...exit_code: 0
# 03/13/26 14:58:39 forward run command(s) finished, took 0.581 seconds
# 03/13/26 14:58:39 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:39 done, took 0.018 seconds
#
#
# -->03/13/26 14:58:39 run complete, took: 0.603 seconds
# -->1 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:39 processing template files with 1 threads...
# 03/13/26 14:58:39 done, took 0.001 seconds
# 03/13/26 14:58:39 calling forward run command(s)
# 03/13/26 14:58:39 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74404
# ...exit_code: 0
# 03/13/26 14:58:40 forward run command(s) finished, took 0.587 seconds
# 03/13/26 14:58:40 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:40 done, took 0.018 seconds
#
#
# -->03/13/26 14:58:40 run complete, took: 0.608 seconds
# -->2 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:40 processing template files with 1 threads...
# 03/13/26 14:58:40 done, took 0.001 seconds
# 03/13/26 14:58:40 calling forward run command(s)
# 03/13/26 14:58:40 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 73888
# ...exit_code: 0
# 03/13/26 14:58:40 forward run command(s) finished, took 0.569 seconds
# 03/13/26 14:58:40 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:40 done, took 0.017 seconds
#
#
# -->03/13/26 14:58:40 run complete, took: 0.589 seconds
# -->3 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:40 processing template files with 1 threads...
# 03/13/26 14:58:40 done, took 0.001 seconds
# 03/13/26 14:58:40 calling forward run command(s)
# 03/13/26 14:58:40 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74632
# ...exit_code: 0
# 03/13/26 14:58:41 forward run command(s) finished, took 0.54 seconds
# 03/13/26 14:58:41 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:41 done, took 0.002 seconds
#
#
# -->03/13/26 14:58:41 run complete, took: 0.546 seconds
# -->4 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:41 processing template files with 1 threads...
# 03/13/26 14:58:41 done, took 0.001 seconds
# 03/13/26 14:58:41 calling forward run command(s)
# 03/13/26 14:58:41 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 54400
# ...exit_code: 0
# 03/13/26 14:58:42 forward run command(s) finished, took 0.556 seconds
# 03/13/26 14:58:42 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:42 done, took 0.013 seconds
#
#
# -->03/13/26 14:58:42 run complete, took: 0.573 seconds
# -->5 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:42 processing template files with 1 threads...
# 03/13/26 14:58:42 done, took 0.002 seconds
# 03/13/26 14:58:42 calling forward run command(s)
# 03/13/26 14:58:42 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 72024
# ...exit_code: 0
# 03/13/26 14:58:42 forward run command(s) finished, took 0.525 seconds
# 03/13/26 14:58:42 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:42 done, took 0.017 seconds
#
#
# -->03/13/26 14:58:42 run complete, took: 0.547 seconds
# -->6 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:42 processing template files with 1 threads...
# 03/13/26 14:58:42 done, took 0.001 seconds
# 03/13/26 14:58:42 calling forward run command(s)
# 03/13/26 14:58:42 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74356
# ...exit_code: 0
# 03/13/26 14:58:43 forward run command(s) finished, took 0.545 seconds
# 03/13/26 14:58:43 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:43 done, took 0.002 seconds
#
#
# -->03/13/26 14:58:43 run complete, took: 0.552 seconds
# -->7 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:43 processing template files with 1 threads...
# 03/13/26 14:58:43 done, took 0.001 seconds
# 03/13/26 14:58:43 calling forward run command(s)
# 03/13/26 14:58:43 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 73192
# ...exit_code: 0
# 03/13/26 14:58:43 forward run command(s) finished, took 0.51 seconds
# 03/13/26 14:58:43 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:43 done, took 0.002 seconds
#
#
# -->03/13/26 14:58:43 run complete, took: 0.516 seconds
# -->8 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:43 processing template files with 1 threads...
# 03/13/26 14:58:43 done, took 0.001 seconds
# 03/13/26 14:58:43 calling forward run command(s)
# 03/13/26 14:58:43 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74692
# ...exit_code: 0
# 03/13/26 14:58:44 forward run command(s) finished, took 0.513 seconds
# 03/13/26 14:58:44 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:44 done, took 0.013 seconds
#
#
# -->03/13/26 14:58:44 run complete, took: 0.53 seconds
# -->9 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:44 processing template files with 1 threads...
# 03/13/26 14:58:44 done, took 0.001 seconds
# 03/13/26 14:58:44 calling forward run command(s)
# 03/13/26 14:58:44 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74932
# ...exit_code: 0
# 03/13/26 14:58:44 forward run command(s) finished, took 0.516 seconds
# 03/13/26 14:58:44 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:44 done, took 0.003 seconds
#
#
# -->03/13/26 14:58:44 run complete, took: 0.523 seconds
# -->10 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:44 processing template files with 1 threads...
# 03/13/26 14:58:44 done, took 0.001 seconds
# 03/13/26 14:58:44 calling forward run command(s)
# 03/13/26 14:58:44 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 75704
# ...exit_code: 0
# 03/13/26 14:58:45 forward run command(s) finished, took 0.513 seconds
# 03/13/26 14:58:45 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:45 done, took 0.013 seconds
#
#
# -->03/13/26 14:58:45 run complete, took: 0.529 seconds
# -->11 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:45 processing template files with 1 threads...
# 03/13/26 14:58:45 done, took 0.001 seconds
# 03/13/26 14:58:45 calling forward run command(s)
# 03/13/26 14:58:45 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74964
# ...exit_code: 0
# 03/13/26 14:58:45 forward run command(s) finished, took 0.517 seconds
# 03/13/26 14:58:45 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:45 done, took 0.02 seconds
#
#
# -->03/13/26 14:58:45 run complete, took: 0.54 seconds
# -->12 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:45 processing template files with 1 threads...
# 03/13/26 14:58:45 done, took 0.001 seconds
# 03/13/26 14:58:45 calling forward run command(s)
# 03/13/26 14:58:45 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 53136
# ...exit_code: 0
# 03/13/26 14:58:46 forward run command(s) finished, took 0.544 seconds
# 03/13/26 14:58:46 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:46 done, took 0.019 seconds
#
#
# -->03/13/26 14:58:46 run complete, took: 0.566 seconds
# -->13 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:46 processing template files with 1 threads...
# 03/13/26 14:58:46 done, took 0.001 seconds
# 03/13/26 14:58:46 calling forward run command(s)
# 03/13/26 14:58:46 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 75848
# ...exit_code: 0
# 03/13/26 14:58:46 forward run command(s) finished, took 0.542 seconds
# 03/13/26 14:58:46 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:46 done, took 0.017 seconds
#
#
# -->03/13/26 14:58:46 run complete, took: 0.562 seconds
# -->14 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:46 processing template files with 1 threads...
# 03/13/26 14:58:46 done, took 0.001 seconds
# 03/13/26 14:58:46 calling forward run command(s)
# 03/13/26 14:58:46 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 76560
# ...exit_code: 0
# 03/13/26 14:58:47 forward run command(s) finished, took 0.56 seconds
# 03/13/26 14:58:47 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:47 done, took 0.02 seconds
#
#
# -->03/13/26 14:58:47 run complete, took: 0.583 seconds
# -->15 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:47 processing template files with 1 threads...
# 03/13/26 14:58:47 done, took 0.001 seconds
# 03/13/26 14:58:47 calling forward run command(s)
# 03/13/26 14:58:47 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 76756
# ...exit_code: 0
# 03/13/26 14:58:48 forward run command(s) finished, took 0.54 seconds
# 03/13/26 14:58:48 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:48 done, took 0.014 seconds
#
#
# -->03/13/26 14:58:48 run complete, took: 0.557 seconds
# -->16 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:48 processing template files with 1 threads...
# 03/13/26 14:58:48 done, took 0.001 seconds
# 03/13/26 14:58:48 calling forward run command(s)
# 03/13/26 14:58:48 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 75892
# ...exit_code: 0
# 03/13/26 14:58:48 forward run command(s) finished, took 0.532 seconds
# 03/13/26 14:58:48 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:48 done, took 0.024 seconds
#
#
# -->03/13/26 14:58:48 run complete, took: 0.559 seconds
# -->17 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:48 processing template files with 1 threads...
# 03/13/26 14:58:48 done, took 0.002 seconds
# 03/13/26 14:58:48 calling forward run command(s)
# 03/13/26 14:58:48 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 73048
# ...exit_code: 0
# 03/13/26 14:58:49 forward run command(s) finished, took 0.601 seconds
# 03/13/26 14:58:49 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:49 done, took 0.018 seconds
#
#
# -->03/13/26 14:58:49 run complete, took: 0.624 seconds
# -->18 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:49 processing template files with 1 threads...
# 03/13/26 14:58:49 done, took 0.001 seconds
# 03/13/26 14:58:49 calling forward run command(s)
# 03/13/26 14:58:49 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 67152
# ...exit_code: 0
# 03/13/26 14:58:49 forward run command(s) finished, took 0.575 seconds
# 03/13/26 14:58:49 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:49 done, took 0.015 seconds
#
#
# -->03/13/26 14:58:49 run complete, took: 0.594 seconds
# -->19 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:49 processing template files with 1 threads...
# 03/13/26 14:58:49 done, took 0.001 seconds
# 03/13/26 14:58:49 calling forward run command(s)
# 03/13/26 14:58:49 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74604
# ...exit_code: 0
# 03/13/26 14:58:50 forward run command(s) finished, took 0.56 seconds
# 03/13/26 14:58:50 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:50 done, took 0.001 seconds
#
#
# -->03/13/26 14:58:50 run complete, took: 0.566 seconds
# -->20 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:50 processing template files with 1 threads...
# 03/13/26 14:58:50 done, took 0.001 seconds
# 03/13/26 14:58:50 calling forward run command(s)
# 03/13/26 14:58:50 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 76664
# ...exit_code: 0
# 03/13/26 14:58:50 forward run command(s) finished, took 0.544 seconds
# 03/13/26 14:58:50 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:50 done, took 0.016 seconds
#
#
# -->03/13/26 14:58:50 run complete, took: 0.563 seconds
# -->21 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:50 processing template files with 1 threads...
# 03/13/26 14:58:50 done, took 0.001 seconds
# 03/13/26 14:58:50 calling forward run command(s)
# 03/13/26 14:58:50 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 64528
# ...exit_code: 0
# 03/13/26 14:58:51 forward run command(s) finished, took 0.546 seconds
# 03/13/26 14:58:51 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:51 done, took 0.019 seconds
#
#
# -->03/13/26 14:58:51 run complete, took: 0.568 seconds
# -->22 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:51 processing template files with 1 threads...
# 03/13/26 14:58:51 done, took 0.001 seconds
# 03/13/26 14:58:51 calling forward run command(s)
# 03/13/26 14:58:51 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 71888
# ...exit_code: 0
# 03/13/26 14:58:52 forward run command(s) finished, took 0.542 seconds
# 03/13/26 14:58:52 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:52 done, took 0.018 seconds
#
#
# -->03/13/26 14:58:52 run complete, took: 0.563 seconds
# -->23 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:52 processing template files with 1 threads...
# 03/13/26 14:58:52 done, took 0.001 seconds
# 03/13/26 14:58:52 calling forward run command(s)
# 03/13/26 14:58:52 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 77232
# ...exit_code: 0
# 03/13/26 14:58:52 forward run command(s) finished, took 0.545 seconds
# 03/13/26 14:58:52 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:52 done, took 0.021 seconds
#
#
# -->03/13/26 14:58:52 run complete, took: 0.569 seconds
# -->24 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:52 processing template files with 1 threads...
# 03/13/26 14:58:52 done, took 0.001 seconds
# 03/13/26 14:58:52 calling forward run command(s)
# 03/13/26 14:58:52 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 77300
# ...exit_code: 0
# 03/13/26 14:58:53 forward run command(s) finished, took 0.522 seconds
# 03/13/26 14:58:53 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:53 done, took 0.015 seconds
#
#
# -->03/13/26 14:58:53 run complete, took: 0.541 seconds
# -->25 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:53 processing template files with 1 threads...
# 03/13/26 14:58:53 done, took 0.003 seconds
# 03/13/26 14:58:53 calling forward run command(s)
# 03/13/26 14:58:53 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 72108
# ...exit_code: 0
# 03/13/26 14:58:53 forward run command(s) finished, took 0.526 seconds
# 03/13/26 14:58:53 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:53 done, took 0.019 seconds
#
#
# -->03/13/26 14:58:53 run complete, took: 0.553 seconds
# -->26 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:53 processing template files with 1 threads...
# 03/13/26 14:58:53 done, took 0.003 seconds
# 03/13/26 14:58:53 calling forward run command(s)
# 03/13/26 14:58:53 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 73476
# ...exit_code: 0
# 03/13/26 14:58:54 forward run command(s) finished, took 0.52 seconds
# 03/13/26 14:58:54 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:54 done, took 0.02 seconds
#
#
# -->03/13/26 14:58:54 run complete, took: 0.548 seconds
# -->27 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:54 processing template files with 1 threads...
# 03/13/26 14:58:54 done, took 0.003 seconds
# 03/13/26 14:58:54 calling forward run command(s)
# 03/13/26 14:58:54 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74860
# ...exit_code: 0
# 03/13/26 14:58:54 forward run command(s) finished, took 0.551 seconds
# 03/13/26 14:58:54 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:54 done, took 0.018 seconds
#
#
# -->03/13/26 14:58:54 run complete, took: 0.577 seconds
# -->28 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:54 processing template files with 1 threads...
# 03/13/26 14:58:54 done, took 0.003 seconds
# 03/13/26 14:58:54 calling forward run command(s)
# 03/13/26 14:58:54 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 75076
# ...exit_code: 0
# 03/13/26 14:58:55 forward run command(s) finished, took 0.526 seconds
# 03/13/26 14:58:55 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:55 done, took 0.002 seconds
#
#
# -->03/13/26 14:58:55 run complete, took: 0.537 seconds
# -->29 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:55 processing template files with 1 threads...
# 03/13/26 14:58:55 done, took 0.004 seconds
# 03/13/26 14:58:55 calling forward run command(s)
# 03/13/26 14:58:55 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 36416
# ...exit_code: 0
# 03/13/26 14:58:55 forward run command(s) finished, took 0.54 seconds
# 03/13/26 14:58:55 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:55 done, took 0.005 seconds
#
#
# -->03/13/26 14:58:55 run complete, took: 0.552 seconds
# -->30 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:55 processing template files with 1 threads...
# 03/13/26 14:58:55 done, took 0.006 seconds
# 03/13/26 14:58:55 calling forward run command(s)
# 03/13/26 14:58:55 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 76424
# ...exit_code: 0
# 03/13/26 14:58:56 forward run command(s) finished, took 0.529 seconds
# 03/13/26 14:58:56 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:56 done, took 0.02 seconds
#
#
# -->03/13/26 14:58:56 run complete, took: 0.56 seconds
# -->31 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:56 processing template files with 1 threads...
# 03/13/26 14:58:56 done, took 0.004 seconds
# 03/13/26 14:58:56 calling forward run command(s)
# 03/13/26 14:58:56 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 47004
# ...exit_code: 0
# 03/13/26 14:58:57 forward run command(s) finished, took 0.536 seconds
# 03/13/26 14:58:57 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:57 done, took 0.001 seconds
#
#
# -->03/13/26 14:58:57 run complete, took: 0.545 seconds
# -->32 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:57 processing template files with 1 threads...
# 03/13/26 14:58:57 done, took 0.002 seconds
# 03/13/26 14:58:57 calling forward run command(s)
# 03/13/26 14:58:57 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 12344
# ...exit_code: 0
# 03/13/26 14:58:57 forward run command(s) finished, took 0.566 seconds
# 03/13/26 14:58:57 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:57 done, took 0.021 seconds
#
#
# -->03/13/26 14:58:57 run complete, took: 0.592 seconds
# -->33 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:57 processing template files with 1 threads...
# 03/13/26 14:58:57 done, took 0.002 seconds
# 03/13/26 14:58:57 calling forward run command(s)
# 03/13/26 14:58:57 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 77668
# ...exit_code: 0
# 03/13/26 14:58:58 forward run command(s) finished, took 0.533 seconds
# 03/13/26 14:58:58 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:58 done, took 0.019 seconds
#
#
# -->03/13/26 14:58:58 run complete, took: 0.558 seconds
# -->34 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:58 processing template files with 1 threads...
# 03/13/26 14:58:58 done, took 0.003 seconds
# 03/13/26 14:58:58 calling forward run command(s)
# 03/13/26 14:58:58 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 71428
# ...exit_code: 0
# 03/13/26 14:58:58 forward run command(s) finished, took 0.532 seconds
# 03/13/26 14:58:58 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:58 done, took 0.02 seconds
#
#
# -->03/13/26 14:58:58 run complete, took: 0.561 seconds
# -->35 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:58 processing template files with 1 threads...
# 03/13/26 14:58:58 done, took 0.002 seconds
# 03/13/26 14:58:58 calling forward run command(s)
# 03/13/26 14:58:58 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 75336
# ...exit_code: 0
# 03/13/26 14:58:59 forward run command(s) finished, took 0.537 seconds
# 03/13/26 14:58:59 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:59 done, took 0.016 seconds
#
#
# -->03/13/26 14:58:59 run complete, took: 0.559 seconds
# -->36 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:59 processing template files with 1 threads...
# 03/13/26 14:58:59 done, took 0.002 seconds
# 03/13/26 14:58:59 calling forward run command(s)
# 03/13/26 14:58:59 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 76364
# ...exit_code: 0
# 03/13/26 14:58:59 forward run command(s) finished, took 0.528 seconds
# 03/13/26 14:58:59 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:58:59 done, took 0.018 seconds
#
#
# -->03/13/26 14:58:59 run complete, took: 0.551 seconds
# -->37 of 100 complete, 0 failed
#
#
# 03/13/26 14:58:59 processing template files with 1 threads...
# 03/13/26 14:58:59 done, took 0.004 seconds
# 03/13/26 14:58:59 calling forward run command(s)
# 03/13/26 14:58:59 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 67488
# ...exit_code: 0
# 03/13/26 14:59:00 forward run command(s) finished, took 0.58 seconds
# 03/13/26 14:59:00 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:00 done, took 0.015 seconds
#
#
# -->03/13/26 14:59:00 run complete, took: 0.603 seconds
# -->38 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:00 processing template files with 1 threads...
# 03/13/26 14:59:00 done, took 0.003 seconds
# 03/13/26 14:59:00 calling forward run command(s)
# 03/13/26 14:59:00 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 77548
# ...exit_code: 0
# 03/13/26 14:59:01 forward run command(s) finished, took 0.604 seconds
# 03/13/26 14:59:01 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:01 done, took 0.015 seconds
#
#
# -->03/13/26 14:59:01 run complete, took: 0.626 seconds
# -->39 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:01 processing template files with 1 threads...
# 03/13/26 14:59:01 done, took 0.002 seconds
# 03/13/26 14:59:01 calling forward run command(s)
# 03/13/26 14:59:01 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 77124
# ...exit_code: 0
# 03/13/26 14:59:01 forward run command(s) finished, took 0.53 seconds
# 03/13/26 14:59:01 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:01 done, took 0.002 seconds
#
#
# -->03/13/26 14:59:01 run complete, took: 0.537 seconds
# -->40 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:01 processing template files with 1 threads...
# 03/13/26 14:59:01 done, took 0.002 seconds
# 03/13/26 14:59:01 calling forward run command(s)
# 03/13/26 14:59:01 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 78812
# ...exit_code: 0
# 03/13/26 14:59:02 forward run command(s) finished, took 0.526 seconds
# 03/13/26 14:59:02 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:02 done, took 0.013 seconds
#
#
# -->03/13/26 14:59:02 run complete, took: 0.544 seconds
# -->41 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:02 processing template files with 1 threads...
# 03/13/26 14:59:02 done, took 0.003 seconds
# 03/13/26 14:59:02 calling forward run command(s)
# 03/13/26 14:59:02 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 78244
# ...exit_code: 0
# 03/13/26 14:59:02 forward run command(s) finished, took 0.529 seconds
# 03/13/26 14:59:02 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:02 done, took 0.02 seconds
#
#
# -->03/13/26 14:59:02 run complete, took: 0.556 seconds
# -->42 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:02 processing template files with 1 threads...
# 03/13/26 14:59:02 done, took 0.004 seconds
# 03/13/26 14:59:02 calling forward run command(s)
# 03/13/26 14:59:02 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 78516
# ...exit_code: 0
# 03/13/26 14:59:03 forward run command(s) finished, took 0.531 seconds
# 03/13/26 14:59:03 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:03 done, took 0.023 seconds
#
#
# -->03/13/26 14:59:03 run complete, took: 0.565 seconds
# -->43 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:03 processing template files with 1 threads...
# 03/13/26 14:59:03 done, took 0.004 seconds
# 03/13/26 14:59:03 calling forward run command(s)
# 03/13/26 14:59:03 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 78112
# ...exit_code: 0
# 03/13/26 14:59:03 forward run command(s) finished, took 0.529 seconds
# 03/13/26 14:59:03 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:03 done, took 0.005 seconds
#
#
# -->03/13/26 14:59:03 run complete, took: 0.543 seconds
# -->44 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:03 processing template files with 1 threads...
# 03/13/26 14:59:03 done, took 0.004 seconds
# 03/13/26 14:59:03 calling forward run command(s)
# 03/13/26 14:59:03 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 77572
# ...exit_code: 0
# 03/13/26 14:59:04 forward run command(s) finished, took 0.531 seconds
# 03/13/26 14:59:04 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:04 done, took 0.013 seconds
#
#
# -->03/13/26 14:59:04 run complete, took: 0.554 seconds
# -->45 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:04 processing template files with 1 threads...
# 03/13/26 14:59:04 done, took 0.003 seconds
# 03/13/26 14:59:04 calling forward run command(s)
# 03/13/26 14:59:04 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 76332
# ...exit_code: 0
# 03/13/26 14:59:04 forward run command(s) finished, took 0.511 seconds
# 03/13/26 14:59:04 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:04 done, took 0.002 seconds
#
#
# -->03/13/26 14:59:04 run complete, took: 0.521 seconds
# -->46 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:04 processing template files with 1 threads...
# 03/13/26 14:59:04 done, took 0.002 seconds
# 03/13/26 14:59:04 calling forward run command(s)
# 03/13/26 14:59:04 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 79236
# ...exit_code: 0
# 03/13/26 14:59:05 forward run command(s) finished, took 0.52 seconds
# 03/13/26 14:59:05 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:05 done, took 0.003 seconds
#
#
# -->03/13/26 14:59:05 run complete, took: 0.528 seconds
# -->47 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:05 processing template files with 1 threads...
# 03/13/26 14:59:05 done, took 0.004 seconds
# 03/13/26 14:59:05 calling forward run command(s)
# 03/13/26 14:59:05 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 77456
# ...exit_code: 0
# 03/13/26 14:59:06 forward run command(s) finished, took 0.515 seconds
# 03/13/26 14:59:06 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:06 done, took 0.019 seconds
#
#
# -->03/13/26 14:59:06 run complete, took: 0.545 seconds
# -->48 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:06 processing template files with 1 threads...
# 03/13/26 14:59:06 done, took 0.002 seconds
# 03/13/26 14:59:06 calling forward run command(s)
# 03/13/26 14:59:06 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 64496
# ...exit_code: 0
# 03/13/26 14:59:06 forward run command(s) finished, took 0.599 seconds
# 03/13/26 14:59:06 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:06 done, took 0.016 seconds
#
#
# -->03/13/26 14:59:06 run complete, took: 0.62 seconds
# -->49 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:06 processing template files with 1 threads...
# 03/13/26 14:59:06 done, took 0.001 seconds
# 03/13/26 14:59:06 calling forward run command(s)
# 03/13/26 14:59:06 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 80600
# ...exit_code: 0
# 03/13/26 14:59:07 forward run command(s) finished, took 0.542 seconds
# 03/13/26 14:59:07 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:07 done, took 0.019 seconds
#
#
# -->03/13/26 14:59:07 run complete, took: 0.564 seconds
# -->50 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:07 processing template files with 1 threads...
# 03/13/26 14:59:07 done, took 0.001 seconds
# 03/13/26 14:59:07 calling forward run command(s)
# 03/13/26 14:59:07 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 79972
# ...exit_code: 0
# 03/13/26 14:59:07 forward run command(s) finished, took 0.537 seconds
# 03/13/26 14:59:07 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:07 done, took 0.001 seconds
#
#
# -->03/13/26 14:59:07 run complete, took: 0.542 seconds
# -->51 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:07 processing template files with 1 threads...
# 03/13/26 14:59:07 done, took 0.001 seconds
# 03/13/26 14:59:07 calling forward run command(s)
# 03/13/26 14:59:07 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 80772
# ...exit_code: 0
# 03/13/26 14:59:08 forward run command(s) finished, took 0.562 seconds
# 03/13/26 14:59:08 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:08 done, took 0.022 seconds
#
#
# -->03/13/26 14:59:08 run complete, took: 0.586 seconds
# -->52 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:08 processing template files with 1 threads...
# 03/13/26 14:59:08 done, took 0.001 seconds
# 03/13/26 14:59:08 calling forward run command(s)
# 03/13/26 14:59:08 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 80456
# ...exit_code: 0
# 03/13/26 14:59:08 forward run command(s) finished, took 0.539 seconds
# 03/13/26 14:59:08 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:08 done, took 0.023 seconds
#
#
# -->03/13/26 14:59:08 run complete, took: 0.565 seconds
# -->53 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:08 processing template files with 1 threads...
# 03/13/26 14:59:08 done, took 0.001 seconds
# 03/13/26 14:59:08 calling forward run command(s)
# 03/13/26 14:59:08 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 61332
# ...exit_code: 0
# 03/13/26 14:59:09 forward run command(s) finished, took 0.522 seconds
# 03/13/26 14:59:09 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:09 done, took 0.02 seconds
#
#
# -->03/13/26 14:59:09 run complete, took: 0.545 seconds
# -->54 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:09 processing template files with 1 threads...
# 03/13/26 14:59:09 done, took 0.001 seconds
# 03/13/26 14:59:09 calling forward run command(s)
# 03/13/26 14:59:09 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 78456
# ...exit_code: 0
# 03/13/26 14:59:10 forward run command(s) finished, took 0.541 seconds
# 03/13/26 14:59:10 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:10 done, took 0.022 seconds
#
#
# -->03/13/26 14:59:10 run complete, took: 0.567 seconds
# -->55 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:10 processing template files with 1 threads...
# 03/13/26 14:59:10 done, took 0.001 seconds
# 03/13/26 14:59:10 calling forward run command(s)
# 03/13/26 14:59:10 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 70272
# ...exit_code: 0
# 03/13/26 14:59:10 forward run command(s) finished, took 0.522 seconds
# 03/13/26 14:59:10 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:10 done, took 0.013 seconds
#
#
# -->03/13/26 14:59:10 run complete, took: 0.54 seconds
# -->56 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:10 processing template files with 1 threads...
# 03/13/26 14:59:10 done, took 0.001 seconds
# 03/13/26 14:59:10 calling forward run command(s)
# 03/13/26 14:59:10 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 79980
# ...exit_code: 0
# 03/13/26 14:59:11 forward run command(s) finished, took 0.517 seconds
# 03/13/26 14:59:11 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:11 done, took 0.018 seconds
#
#
# -->03/13/26 14:59:11 run complete, took: 0.539 seconds
# -->57 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:11 processing template files with 1 threads...
# 03/13/26 14:59:11 done, took 0.002 seconds
# 03/13/26 14:59:11 calling forward run command(s)
# 03/13/26 14:59:11 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 79448
# ...exit_code: 0
# 03/13/26 14:59:11 forward run command(s) finished, took 0.556 seconds
# 03/13/26 14:59:11 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:11 done, took 0.014 seconds
#
#
# -->03/13/26 14:59:11 run complete, took: 0.575 seconds
# -->58 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:11 processing template files with 1 threads...
# 03/13/26 14:59:11 done, took 0.001 seconds
# 03/13/26 14:59:11 calling forward run command(s)
# 03/13/26 14:59:11 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 77656
# ...exit_code: 0
# 03/13/26 14:59:12 forward run command(s) finished, took 0.514 seconds
# 03/13/26 14:59:12 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:12 done, took 0.02 seconds
#
#
# -->03/13/26 14:59:12 run complete, took: 0.537 seconds
# -->59 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:12 processing template files with 1 threads...
# 03/13/26 14:59:12 done, took 0.001 seconds
# 03/13/26 14:59:12 calling forward run command(s)
# 03/13/26 14:59:12 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 64604
# ...exit_code: 0
# 03/13/26 14:59:12 forward run command(s) finished, took 0.524 seconds
# 03/13/26 14:59:12 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:12 done, took 0.001 seconds
#
#
# -->03/13/26 14:59:12 run complete, took: 0.529 seconds
# -->60 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:12 processing template files with 1 threads...
# 03/13/26 14:59:12 done, took 0.002 seconds
# 03/13/26 14:59:12 calling forward run command(s)
# 03/13/26 14:59:12 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 74872
# ...exit_code: 0
# 03/13/26 14:59:13 forward run command(s) finished, took 0.542 seconds
# 03/13/26 14:59:13 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:13 done, took 0.02 seconds
#
#
# -->03/13/26 14:59:13 run complete, took: 0.566 seconds
# -->61 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:13 processing template files with 1 threads...
# 03/13/26 14:59:13 done, took 0.001 seconds
# 03/13/26 14:59:13 calling forward run command(s)
# 03/13/26 14:59:13 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 56896
# ...exit_code: 0
# 03/13/26 14:59:13 forward run command(s) finished, took 0.538 seconds
# 03/13/26 14:59:13 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:13 done, took 0.021 seconds
#
#
# -->03/13/26 14:59:13 run complete, took: 0.562 seconds
# -->62 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:13 processing template files with 1 threads...
# 03/13/26 14:59:13 done, took 0.001 seconds
# 03/13/26 14:59:13 calling forward run command(s)
# 03/13/26 14:59:13 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 79472
# ...exit_code: 0
# 03/13/26 14:59:14 forward run command(s) finished, took 0.538 seconds
# 03/13/26 14:59:14 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:14 done, took 0.016 seconds
#
#
# -->03/13/26 14:59:14 run complete, took: 0.556 seconds
# -->63 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:14 processing template files with 1 threads...
# 03/13/26 14:59:14 done, took 0.001 seconds
# 03/13/26 14:59:14 calling forward run command(s)
# 03/13/26 14:59:14 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 79016
# ...exit_code: 0
# 03/13/26 14:59:15 forward run command(s) finished, took 0.541 seconds
# 03/13/26 14:59:15 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:15 done, took 0.026 seconds
#
#
# -->03/13/26 14:59:15 run complete, took: 0.57 seconds
# -->64 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:15 processing template files with 1 threads...
# 03/13/26 14:59:15 done, took 0.002 seconds
# 03/13/26 14:59:15 calling forward run command(s)
# 03/13/26 14:59:15 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 34556
# ...exit_code: 0
# 03/13/26 14:59:15 forward run command(s) finished, took 0.563 seconds
# 03/13/26 14:59:15 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:15 done, took 0.014 seconds
#
#
# -->03/13/26 14:59:15 run complete, took: 0.581 seconds
# -->65 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:15 processing template files with 1 threads...
# 03/13/26 14:59:15 done, took 0.001 seconds
# 03/13/26 14:59:15 calling forward run command(s)
# 03/13/26 14:59:15 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 80216
# ...exit_code: 0
# 03/13/26 14:59:16 forward run command(s) finished, took 0.529 seconds
# 03/13/26 14:59:16 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:16 done, took 0.021 seconds
#
#
# -->03/13/26 14:59:16 run complete, took: 0.553 seconds
# -->66 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:16 processing template files with 1 threads...
# 03/13/26 14:59:16 done, took 0.001 seconds
# 03/13/26 14:59:16 calling forward run command(s)
# 03/13/26 14:59:16 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 80044
# ...exit_code: 0
# 03/13/26 14:59:16 forward run command(s) finished, took 0.525 seconds
# 03/13/26 14:59:16 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:16 done, took 0.001 seconds
#
#
# -->03/13/26 14:59:16 run complete, took: 0.53 seconds
# -->67 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:16 processing template files with 1 threads...
# 03/13/26 14:59:16 done, took 0.002 seconds
# 03/13/26 14:59:16 calling forward run command(s)
# 03/13/26 14:59:16 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 80144
# ...exit_code: 0
# 03/13/26 14:59:17 forward run command(s) finished, took 0.511 seconds
# 03/13/26 14:59:17 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:17 done, took 0.002 seconds
#
#
# -->03/13/26 14:59:17 run complete, took: 0.518 seconds
# -->68 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:17 processing template files with 1 threads...
# 03/13/26 14:59:17 done, took 0.001 seconds
# 03/13/26 14:59:17 calling forward run command(s)
# 03/13/26 14:59:17 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 42024
# ...exit_code: 0
# 03/13/26 14:59:17 forward run command(s) finished, took 0.512 seconds
# 03/13/26 14:59:17 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:17 done, took 0.017 seconds
#
#
# -->03/13/26 14:59:17 run complete, took: 0.533 seconds
# -->69 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:17 processing template files with 1 threads...
# 03/13/26 14:59:17 done, took 0.002 seconds
# 03/13/26 14:59:17 calling forward run command(s)
# 03/13/26 14:59:17 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 75320
# ...exit_code: 0
# 03/13/26 14:59:18 forward run command(s) finished, took 0.51 seconds
# 03/13/26 14:59:18 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:18 done, took 0.003 seconds
#
#
# -->03/13/26 14:59:18 run complete, took: 0.517 seconds
# -->70 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:18 processing template files with 1 threads...
# 03/13/26 14:59:18 done, took 0.001 seconds
# 03/13/26 14:59:18 calling forward run command(s)
# 03/13/26 14:59:18 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 39832
# ...exit_code: 0
# 03/13/26 14:59:18 forward run command(s) finished, took 0.526 seconds
# 03/13/26 14:59:18 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:18 done, took 0.019 seconds
#
#
# -->03/13/26 14:59:18 run complete, took: 0.548 seconds
# -->71 of 100 complete, 0 failed
#
#
# 03/13/26 14:59:18 processing template files with 1 threads...
# 03/13/26 14:59:18 done, took 0.001 seconds
# 03/13/26 14:59:18 calling forward run command(s)
# 03/13/26 14:59:18 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 34940
# ...exit_code: 0
# 03/13/26 14:59:19 forward run command(s) finished, took 0.524 seconds
# 03/13/26 14:59:19 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 14:59:19 done, took 0.016 seconds
#
#
# ...
# 03/13/26 15:01:14 done, took 0.001 seconds
# 03/13/26 15:01:14 calling forward run command(s)
# 03/13/26 15:01:14 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 37340
# ...exit_code: 0
# 03/13/26 15:01:15 forward run command(s) finished, took 0.554 seconds
# 03/13/26 15:01:15 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:15 done, took 0.018 seconds
#
#
# -->03/13/26 15:01:15 run complete, took: 0.576 seconds
# -->81 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:15 processing template files with 1 threads...
# 03/13/26 15:01:15 done, took 0.001 seconds
# 03/13/26 15:01:15 calling forward run command(s)
# 03/13/26 15:01:15 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 47508
# ...exit_code: 0
# 03/13/26 15:01:15 forward run command(s) finished, took 0.539 seconds
# 03/13/26 15:01:15 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:15 done, took 0.023 seconds
#
#
# -->03/13/26 15:01:15 run complete, took: 0.566 seconds
# -->82 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:15 processing template files with 1 threads...
# 03/13/26 15:01:15 done, took 0.001 seconds
# 03/13/26 15:01:15 calling forward run command(s)
# 03/13/26 15:01:15 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 72168
# ...exit_code: 0
# 03/13/26 15:01:16 forward run command(s) finished, took 0.562 seconds
# 03/13/26 15:01:16 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:16 done, took 0.001 seconds
#
#
# -->03/13/26 15:01:16 run complete, took: 0.567 seconds
# -->83 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:16 processing template files with 1 threads...
# 03/13/26 15:01:16 done, took 0.001 seconds
# 03/13/26 15:01:16 calling forward run command(s)
# 03/13/26 15:01:16 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 50548
# ...exit_code: 0
# 03/13/26 15:01:16 forward run command(s) finished, took 0.526 seconds
# 03/13/26 15:01:16 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:16 done, took 0.001 seconds
#
#
# -->03/13/26 15:01:16 run complete, took: 0.53 seconds
# -->84 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:16 processing template files with 1 threads...
# 03/13/26 15:01:16 done, took 0.001 seconds
# 03/13/26 15:01:16 calling forward run command(s)
# 03/13/26 15:01:16 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 60908
# ...exit_code: 0
# 03/13/26 15:01:17 forward run command(s) finished, took 0.527 seconds
# 03/13/26 15:01:17 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:17 done, took 0.001 seconds
#
#
# -->03/13/26 15:01:17 run complete, took: 0.531 seconds
# -->85 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:17 processing template files with 1 threads...
# 03/13/26 15:01:17 done, took 0.001 seconds
# 03/13/26 15:01:17 calling forward run command(s)
# 03/13/26 15:01:17 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 61264
# ...exit_code: 0
# 03/13/26 15:01:17 forward run command(s) finished, took 0.524 seconds
# 03/13/26 15:01:17 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:17 done, took 0.002 seconds
#
#
# -->03/13/26 15:01:17 run complete, took: 0.529 seconds
# -->86 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:17 processing template files with 1 threads...
# 03/13/26 15:01:17 done, took 0.001 seconds
# 03/13/26 15:01:17 calling forward run command(s)
# 03/13/26 15:01:17 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 57268
# ...exit_code: 0
# 03/13/26 15:01:18 forward run command(s) finished, took 0.542 seconds
# 03/13/26 15:01:18 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:18 done, took 0.02 seconds
#
#
# -->03/13/26 15:01:18 run complete, took: 0.566 seconds
# -->87 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:18 processing template files with 1 threads...
# 03/13/26 15:01:18 done, took 0.001 seconds
# 03/13/26 15:01:18 calling forward run command(s)
# 03/13/26 15:01:18 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 54996
# ...exit_code: 0
# 03/13/26 15:01:18 forward run command(s) finished, took 0.522 seconds
# 03/13/26 15:01:18 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:18 done, took 0.001 seconds
#
#
# -->03/13/26 15:01:18 run complete, took: 0.528 seconds
# -->88 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:18 processing template files with 1 threads...
# 03/13/26 15:01:18 done, took 0.001 seconds
# 03/13/26 15:01:18 calling forward run command(s)
# 03/13/26 15:01:18 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 55500
# ...exit_code: 0
# 03/13/26 15:01:19 forward run command(s) finished, took 0.526 seconds
# 03/13/26 15:01:19 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:19 done, took 0.017 seconds
#
#
# -->03/13/26 15:01:19 run complete, took: 0.546 seconds
# -->89 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:19 processing template files with 1 threads...
# 03/13/26 15:01:19 done, took 0.001 seconds
# 03/13/26 15:01:19 calling forward run command(s)
# 03/13/26 15:01:19 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 37296
# ...exit_code: 0
# 03/13/26 15:01:20 forward run command(s) finished, took 0.525 seconds
# 03/13/26 15:01:20 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:20 done, took 0.002 seconds
#
#
# -->03/13/26 15:01:20 run complete, took: 0.53 seconds
# -->90 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:20 processing template files with 1 threads...
# 03/13/26 15:01:20 done, took 0.002 seconds
# 03/13/26 15:01:20 calling forward run command(s)
# 03/13/26 15:01:20 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 45552
# ...exit_code: 0
# 03/13/26 15:01:20 forward run command(s) finished, took 0.524 seconds
# 03/13/26 15:01:20 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:20 done, took 0.001 seconds
#
#
# -->03/13/26 15:01:20 run complete, took: 0.529 seconds
# -->91 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:20 processing template files with 1 threads...
# 03/13/26 15:01:20 done, took 0.001 seconds
# 03/13/26 15:01:20 calling forward run command(s)
# 03/13/26 15:01:20 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 43236
# ...exit_code: 0
# 03/13/26 15:01:21 forward run command(s) finished, took 0.524 seconds
# 03/13/26 15:01:21 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:21 done, took 0.001 seconds
#
#
# -->03/13/26 15:01:21 run complete, took: 0.529 seconds
# -->92 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:21 processing template files with 1 threads...
# 03/13/26 15:01:21 done, took 0.001 seconds
# 03/13/26 15:01:21 calling forward run command(s)
# 03/13/26 15:01:21 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 57020
# ...exit_code: 0
# 03/13/26 15:01:21 forward run command(s) finished, took 0.527 seconds
# 03/13/26 15:01:21 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:21 done, took 0.016 seconds
#
#
# -->03/13/26 15:01:21 run complete, took: 0.546 seconds
# -->93 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:21 processing template files with 1 threads...
# 03/13/26 15:01:21 done, took 0.001 seconds
# 03/13/26 15:01:21 calling forward run command(s)
# 03/13/26 15:01:21 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 61548
# ...exit_code: 0
# 03/13/26 15:01:22 forward run command(s) finished, took 0.526 seconds
# 03/13/26 15:01:22 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:22 done, took 0.016 seconds
#
#
# -->03/13/26 15:01:22 run complete, took: 0.546 seconds
# -->94 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:22 processing template files with 1 threads...
# 03/13/26 15:01:22 done, took 0.001 seconds
# 03/13/26 15:01:22 calling forward run command(s)
# 03/13/26 15:01:22 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 24368
# ...exit_code: 0
# 03/13/26 15:01:22 forward run command(s) finished, took 0.545 seconds
# 03/13/26 15:01:22 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:22 done, took 0.002 seconds
#
#
# -->03/13/26 15:01:22 run complete, took: 0.55 seconds
# -->95 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:22 processing template files with 1 threads...
# 03/13/26 15:01:22 done, took 0.001 seconds
# 03/13/26 15:01:22 calling forward run command(s)
# 03/13/26 15:01:22 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 52752
# ...exit_code: 0
# 03/13/26 15:01:23 forward run command(s) finished, took 0.542 seconds
# 03/13/26 15:01:23 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:23 done, took 0.023 seconds
#
#
# -->03/13/26 15:01:23 run complete, took: 0.569 seconds
# -->96 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:23 processing template files with 1 threads...
# 03/13/26 15:01:23 done, took 0.001 seconds
# 03/13/26 15:01:23 calling forward run command(s)
# 03/13/26 15:01:23 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 59076
# ...exit_code: 0
# 03/13/26 15:01:23 forward run command(s) finished, took 0.523 seconds
# 03/13/26 15:01:23 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:23 done, took 0.002 seconds
#
#
# -->03/13/26 15:01:23 run complete, took: 0.529 seconds
# -->97 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:23 processing template files with 1 threads...
# 03/13/26 15:01:23 done, took 0.001 seconds
# 03/13/26 15:01:23 calling forward run command(s)
# 03/13/26 15:01:23 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 60548
# ...exit_code: 0
# 03/13/26 15:01:24 forward run command(s) finished, took 0.54 seconds
# 03/13/26 15:01:24 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:24 done, took 0.001 seconds
#
#
# -->03/13/26 15:01:24 run complete, took: 0.544 seconds
# -->98 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:24 processing template files with 1 threads...
# 03/13/26 15:01:24 done, took 0.001 seconds
# 03/13/26 15:01:24 calling forward run command(s)
# 03/13/26 15:01:24 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 61644
# ...exit_code: 0
# 03/13/26 15:01:24 forward run command(s) finished, took 0.544 seconds
# 03/13/26 15:01:24 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:24 done, took 0.001 seconds
#
#
# -->03/13/26 15:01:24 run complete, took: 0.549 seconds
# -->99 of 100 complete, 0 failed
#
#
# 03/13/26 15:01:24 processing template files with 1 threads...
# 03/13/26 15:01:24 done, took 0.001 seconds
# 03/13/26 15:01:24 calling forward run command(s)
# 03/13/26 15:01:24 calling forward run command: 'c:\Users\kaden.mcculloch\AppData\Local\anaconda3\envs\kfmcculloch98\python.exe run_theis_forward.py'
# ...pid: 61552
# ...exit_code: 0
# 03/13/26 15:01:25 forward run command(s) finished, took 0.562 seconds
# 03/13/26 15:01:25 processing instruction files with 1 threads...
# thread 0 processed 1 instruction files
# 03/13/26 15:01:25 done, took 0.015 seconds
#
#
# -->03/13/26 15:01:25 run complete, took: 0.579 seconds
# -->100 of 100 complete, 0 failed
#
#
#
#
#
#     ---  serial run manager runs summary:  ---
#     100 of 100 complete, 0 failed
#     process took : 55.901 seconds
#
#
#
#
# ...saved decision variable population of size 100 X 2 to 'baseline.dv_pop.csv'
# ...saved generation-specific decision variable population of size 100 X 2 to 'baseline.2.dv_pop.csv'
# ...saved observation population of size 100 X 2 to 'baseline.obs_pop.csv'
# WARNING: 74 duplicate solutions found, dropping (see rec file for listing)
# WARNING: 74 duplicate solutions found, dropping (see rec file for listing)
# ...pareto dominance sorting combined parent-child populations of size  200
# WARNING: 74 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to baseline.pareto.summary.csv
# updating archive
# adding 1 non-dominated members to archive
# pareto dominance sorting archive of size 2
# WARNING: 1 duplicate solutions found, dropping (see rec file for listing)
# ...wrote pareto summary to baseline.pareto.archive.summary.csv
# resizing archive from 2 to 1 current non-dominated solutions
# ...wrote pareto summary to baseline.pareto.trimmed.archive.summary.csv
# ...saved decision variable population of size 1 X 2 to 'baseline.archive.dv_pop.csv'
# ...saved generation-specific decision variable population of size 1 X 2 to 'baseline.2.archive.dv_pop.csv'
# ...saved observation population of size 1 X 2 to 'baseline.archive.obs_pop.csv'
# ...resizing current populations to  100
#
#   ---  generation 2 decision variable summary:  ---
# decision variable       ubnd      lbnd        mean       stdev         min         max
# WELL_1__R               100000        0.1       1.8736      1.86855    -0.342512            5
# WELL_2__R               100000        0.1      1.93016      1.71633    -0.252274            5
#
#
#   ---  generation 2 decision variable change summary:  ---
# decision variable  mean change   % change max change   % change min change   % change
# WELL_1__R             -0.833005    -80.0512           0           0   -0.657488           0
# WELL_2__R           -0.00583974   -0.303471           0           0   -0.747726           0
#
#
#   ---  generation 2 objective function summary:  ---
# seeking optimal trade-off point for single 'optimal' chance point runs
# using member GEN=2_MEMBER=336_PSO as single, 'optimal' point
#    with distance of 8.63791e-52 from optimal trade - off
# objective function   direction         mean      std dev          min          max         knee
#
# WELL_1                minimize   0.02043457   0.04069759            0     0.172647 8.637911e-52
# WELL_2                minimize   0.01104802   0.02499533            0    0.1392372            0
#
#
#   ---  generation 2 objective function change summary:  ---
# objective function   mean change    % change  max change    % change  min change    % change knee change    % change
# WELL_1                 0.0604804     74.7456    0.622583     78.2897           0           0-8.63791e-52           0
# WELL_2                 0.0568101     83.7189    0.655993      82.491           0           0 2.85769e-33         100
#
# ...number of feasible solutions at the end of generation 2: 1
#
#
# pestpp-mou analysis complete...
# started at 03/13/26 14:58:39
# finished at 03/13/26 15:01:25
# took 2.76667 minutes

# %%
import pyemu
pst = pyemu.Pst("baseline.pst")   # or f"{name}.pst"
r_params = pst.parameter_data.loc[pst.parameter_data.parnme.str.endswith("__r"), ["parnme","parval1","parlbnd","parubnd"]]
print(r_params)
# Out:
#               parnme  parval1  parlbnd   parubnd
# parnme
# well_1__r  well_1__r  2236.07      0.1  100000.0
# well_2__r  well_2__r  6324.56      0.1  100000.0

# %%
# forward_check.py
import yaml, subprocess, sys
from pathlib import Path
import numpy as np

# load pst to get estimated params
import pyemu
pst = pyemu.Pst("baseline.pst")   # or your pst filename

# get estimated radii parameters (parval1)
r_params = pst.parameter_data.loc[pst.parameter_data.parnme.str.endswith("__r"), ["parnme","parval1"]]
print("Estimated parameters:")
print(r_params)

# write proj6.yml with these estimated radii (replace tokens with values)
cfg = yaml.safe_load(Path("proj6.yml").read_text())  # tokenized file
for parn,val in zip(r_params.parnme, r_params.parval1):
    # parn like "well_1__r" -> well key "well_1"
    well = parn.replace("__r","")
    if well in cfg:
        cfg[well]['radial_dist'] = float(val)

# save a temporary proj6_est.yml and run model
tmp = Path("proj6_est.yml")
with tmp.open('w') as f:
    yaml.dump(cfg, f, default_flow_style=False, sort_keys=False)

# run model using same python as in PST
python_exe = pst.model_command[0].split()[0]  # crude parse: "C:\...\python.exe run_theis_forward.py"
proc = subprocess.run([python_exe, "run_theis_forward.py"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
print("Model returncode:", proc.returncode)
if proc.stdout: print("MODEL STDOUT:\n", proc.stdout)
if proc.stderr: print("MODEL STDERR:\n", proc.stderr)

# read model predictions and observations
pred = {}
for ln in Path("allobs.out").read_text().splitlines():
    k,v = ln.split()[:2]
    pred[k] = float(v)

obs = {}
# measured allobs.out was used as obs file; load the same file we kept
for ln in Path("allobs.out").read_text().splitlines():
    k,v = ln.split()[:2]
    obs[k] = float(v)

# compute residuals
print("\nResiduals (obs - pred):")
for k in sorted(obs):
    r = obs[k] - pred.get(k,0.0)
    print(k, "obs=",obs[k], "pred=", pred.get(k, None), "resid=", r)
# Out:
# Estimated parameters:
#               parnme  parval1
# parnme
# well_1__r  well_1__r  2236.07
# well_2__r  well_2__r  6324.56
# Model returncode: 0
#
# Residuals (obs - pred):
# well_1 obs= 8.6379109689393e-52 pred= 8.6379109689393e-52 resid= 0.0
# well_2 obs= 0.0 pred= 0.0 resid= 0.0

# %%
# check_underflow_and_sensitivity.py
import yaml, math
from pathlib import Path

cfg = yaml.safe_load(Path("proj6.yml").read_text())

T = float(cfg.get('T'))
S = float(cfg.get('S'))
t = float(cfg.get('t_eval', 365.0))

print("T =", T, "S =", S, "t_eval =", t)
print()

for k in sorted(cfg):
    if k.startswith("well_"):
        Q = float(cfg[k]['Q'])
        r = float(cfg[k]['radial_dist'])
        u = (r*r*S) / (4.0*T*t)
        try:
            exp_minus_u = math.exp(-u)
        except OverflowError:
            exp_minus_u = 0.0
        flux = (Q / (2.0 * math.pi * r)) * exp_minus_u

        # finite-difference sensitivity dq/dr
        dr = max(abs(r)*1e-6, 1e-9)
        # compute flux_up/down carefully avoiding overflow
        u_up = ((r+dr)*(r+dr)*S) / (4.0*T*t)
        u_dn = ((r-dr)*(r-dr)*S) / (4.0*T*t)
        exp_up = math.exp(-u_up) if u_up < 700 else 0.0
        exp_dn = math.exp(-u_dn) if u_dn < 700 else 0.0
        flux_up = (Q / (2.0*math.pi*(r+dr))) * exp_up
        flux_dn = (Q / (2.0*math.pi*(r-dr))) * exp_dn
        dqdr = (flux_up - flux_dn) / (2*dr)

        print(k)
        print("  Q =", Q)
        print("  r =", r)
        print("  u =", "{:.6e}".format(u))
        print("  exp(-u) =", "{:.6e}".format(exp_minus_u))
        print("  flux =", "{:.6e}".format(flux))
        print("  dq/dr ≈", "{:.6e}".format(dqdr))
        print("  flux == 0.0 ?", flux == 0.0)
        print()
# Out:
# T = 1e-07 S = 1e-05 t_eval = 365.0
#
# well_1
#   Q = 0.5
#   r = 40.32016451492335
#   u = 1.113504e+02
#   exp(-u) = 4.376641e-49
#   flux = 8.637911e-52
#   dq/dr ≈ -4.792410e-51
#   flux == 0.0 ? False
#
# well_2
#   Q = 0.5
#   r = 167.25129811439658
#   u = 1.915959e+03
#   exp(-u) = 0.000000e+00
#   flux = 0.000000e+00
#   dq/dr ≈ 0.000000e+00
#   flux == 0.0 ? True
